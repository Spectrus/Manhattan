# %%
import pandas 
import seaborn  

import numpy as np
import pandas as pd

data = pd.read_json("GCFINAL.json ")
seaborn.relplot (x='dtr' , y ='eTo' , data=data)

# %%
import pandas 
import seaborn  

import numpy as np
import pandas as pd

data = pd.read_json("GGFINAL.json ")
seaborn.relplot (x='dtr' , y ='eTo' , data=data)

# %%
import pandas 
import seaborn  

import numpy as np
import pandas as pd

data = pd.read_json("DFINAL.json")
#print(data)
seaborn.relplot (x='dtr' , y ='eTo' , data=data)

# %%
import pandas 
import seaborn  

import numpy as np
import pandas as pd

data = pd.read_json("ECFINAL.json")

seaborn.relplot (x='eTo' , y ='eTo__1' , data=data)
