# %%
import pandas as pd
import plotly.express as px
import plotly.express as px
import os
import pandas  
 
#Changing the current working directory

df = pandas.read_json("VendaFINALGC.json")
df = df.copy()
 
categorical_col_updated = ['qtd','Data']
#bike = pandas.get_dummies(bike, columns = categorical_col_updated) 
 
#Separating the dependent and independent data variables into two data frames.
from sklearn.model_selection import train_test_split 
  
X =df.drop(['Data'],axis=1) 
Y = df['qtd']
 
#Building the Decision Tree Model on our dataset
from sklearn.tree import DecisionTreeRegressor
X_train, X_test, Y_train, Y_test = train_test_split(df, Y, test_size=0.2,random_state=0)

print (X_test.shape, Y_test.shape)
DT_model = DecisionTreeRegressor(max_depth=5).fit(X_train,Y_train)
DT_predict = DT_model.predict(X_test) #Predictions on Testing data
print(DT_predict)
#! pip install statsmodels
df =pd.read_json("GCFINAL.json")
fig = px.scatter(df, x="dtr", y="eTo", trendline="ols")
fig.show()
df.tail()
# Out:
# (28, 2) (28,)
# [-4379.76923077 -2928.4        -4602.77777778 -3087.66666667
#  -3569.         -3087.66666667 -2623.66666667 -3747.
#  -4767.16666667 -3747.         -3087.66666667 -3569.
#  -5039.77777778 -4602.77777778 -5940.25       -3997.8
#  -5039.77777778 -3466.         -3844.         -4379.76923077
#  -4151.         -3699.         -3350.375      -4151.
#  -4602.77777778 -5940.25       -3087.66666667 -3195.14285714]
#           dtr       eTo
# 153  2022.418  17238.72
# 154  2022.419  13684.89
# 155  2022.420  18684.89
# 156  2022.420  13924.64
# 157  2022.421   9538.00

# %%
import plotly.express as px
import plotly.express as px
import os
import pandas as pd
 
#Changing the current working directory

df = pd.read_json("VendaFINALGG.json")
df = df.copy()
 
categorical_col_updated = ['qtd','dtr']
#bike = pandas.get_dummies(bike, columns = categorical_col_updated) 
 
#Separating the dependent and independent data variables into two data frames.
from sklearn.model_selection import train_test_split 
   
X =df.drop(['qtd'],axis=1) 
Y = df['dtr']

X =df.drop(['dtr'],axis=1) 
Y = df['qtd']

#Building the Decision Tree Model on our dataset
from sklearn.tree import DecisionTreeRegressor
X_train, X_test, Y_train, Y_test = train_test_split(df, Y, test_size=0.2,random_state=0)

print (X_test.shape, Y_test.shape)
DT_model = DecisionTreeRegressor(max_depth=5).fit(X_train,Y_train)
DT_predict = DT_model.predict(X_test) #Predictions on Testing data

print(DT_predict)
#! pip install statsmodels
df =pd.read_json("GGFINAL.json")
fig = px.scatter(df, x="dtr", y="eTo", trendline="ols")
fig.show()
# Out:
# (23, 2) (23,)
# [ -639.66666667 -1110.          -684.66666667  -494.
#   -494.          -965.          -736.33333333  -767.83333333
#   -767.83333333 -1184.5         -865.66666667  -767.83333333
#   -965.          -452.          -919.          -965.
#   -704.44444444  -579.66666667  -452.          -767.83333333
#  -1184.5         -610.          -684.66666667]

# %%
import plotly.express as px
import plotly.express as px
import os
import pandas  as pd
 
#Changing the current working directory

df = pd.read_json("VendaFINALDC.json")
df = df.copy()
 
categorical_col_updated = ['qtd','dtr']
#bike = pandas.get_dummies(bike, columns = categorical_col_updated) 
 
#Separating the dependent and independent data variables into two data frames.
from sklearn.model_selection import train_test_split 
  
X =df.drop(['dtr'],axis=1) 
Y = df['qtd']
 
#Building the Decision Tree Model on our dataset
from sklearn.tree import DecisionTreeRegressor
X_train, X_test, Y_train, Y_test = train_test_split(df, Y, test_size=0.2, random_state=0)

print (X_test.shape, Y_test.shape)
DT_model = DecisionTreeRegressor(max_depth=5).fit(X_train,Y_train)
DT_predict = DT_model.predict(X_test) #Predictions on Testing data
print(DT_predict)

#! pip install statsmodels
df =pd.read_json("DFINAL.json")
fig = px.scatter(df, x="dtr", y="eTo", trendline="ols")
fig.show()
# Out:
# (23, 2) (23,)
# [-1176.8         -852.         -1638.         -1267.8
#  -1097.16666667 -1984.5         -763.5         -370.
#  -1097.16666667 -2053.         -1836.5         -627.25
#   -370.          -918.16666667 -1464.33333333 -1097.16666667
#   -918.16666667 -1176.8         -473.          -627.25
#  -1176.8         -526.         -1399.        ]

# %%
import plotly.express as px
import plotly.express as px
import os
import pandas  as pd
 
#Changing the current working directory

df = pd.read_json("VendaFINALEC.json")
df = df.copy()
 
categorical_col_updated = ['qtd','dtr']
#bike = pandas.get_dummies(bike, columns = categorical_col_updated) 
 
#Separating the dependent and independent data variables into two data frames.
from sklearn.model_selection import train_test_split 
  
X =df.drop(['dtr'],axis=1) 
Y = df['qtd']
 
#Building the Decision Tree Model on our dataset
from sklearn.tree import DecisionTreeRegressor
X_train, X_test, Y_train, Y_test = train_test_split(df, Y, test_size=0.2,random_state=0)

print (X_test.shape, Y_test.shape)
DT_model = DecisionTreeRegressor(max_depth=5).fit(X_train,Y_train)
DT_predict = DT_model.predict(X_test) #Predictions on Testing data
print(DT_predict)

#! pip install statsmodels
df =pd.read_json("ECFINAL.json")
fig = px.scatter(df, x="eTo", y="eTo__1", trendline="ols")
fig.show()
# Out:
# (23, 2) (23,)
# [-2232.66666667 -1073.5        -4891.5        -1731.5
#  -1978.25       -3187.         -2972.         -1073.5
#  -1373.33333333 -5649.         -4891.5        -1978.25
#  -1579.8        -3775.33333333 -2972.         -3187.
#  -1731.5        -2792.4        -3187.         -2390.
#  -2705.66666667  -853.         -2142.4       ]
